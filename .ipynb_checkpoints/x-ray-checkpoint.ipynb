# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets, models, transforms
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
trainname = pd.read_csv('trainname.csv',encoding='utf8')

# %%
for i in range(len(trainname)):
    if trainname['class'][i] == 0:
        trainname.loc[i, 'path'] = './chest_xray/train/NORMAL/'+trainname['path'][i]
    else:
        trainname.loc[i, 'path'] = './chest_xray/train/PNEUMONIA/'+trainname['path'][i]

# %%
x_class = [
    'NORMAL',
    'PNEUMONIA'
]

# %%
plt.figure(figsize=(12,8))
for n, (idx, row) in enumerate(trainname.sample(16).iterrows(), start=1):
    plt.subplot(4,4, n)
    img = plt.imread(row['path'])
    plt.imshow(img)
    plt.title(x_class[row['class']])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
trainname
# Out:
#                                                    path  class
# 0             chest_xray/train/NORMAL/IM-0115-0001.jpeg      0
# 1             chest_xray/train/NORMAL/IM-0117-0001.jpeg      0
# 2             chest_xray/train/NORMAL/IM-0119-0001.jpeg      0
# 3             chest_xray/train/NORMAL/IM-0122-0001.jpeg      0
# 4             chest_xray/train/NORMAL/IM-0125-0001.jpeg      0
# ...                                                 ...    ...
# 5211  chest_xray/train/PNEUMONIA/person99_virus_183....      1
# 5212  chest_xray/train/PNEUMONIA/person9_bacteria_38...      1
# 5213  chest_xray/train/PNEUMONIA/person9_bacteria_39...      1
# 5214  chest_xray/train/PNEUMONIA/person9_bacteria_40...      1
# 5215  chest_xray/train/PNEUMONIA/person9_bacteria_41...      1
#
# [5216 rows x 2 columns]

# %%
import os
import pandas as pd
from torchvision.io import read_image

class CustomImageDataset(Dataset):
    def __init__(self, data, transforms):
        self.data = data
        self.transforms = transforms

    def __len__(self):
        # return len(self.file)
        return self.data.shape[0]

    def __getitem__(self, idx: int): # custom_path : 'train/NORMAL/'
        assert idx <= len(self), 'index range error'

        # img_path = self.file.iloc[idx, 0]
        
        image = plt.imread(self.data.iloc[idx, ]['path']) ## PIL 불러오기
        image = transforms.ToPILImage()(image)

        target = torch.as_tensor(self.data.iloc[idx, ]['class'])

        if self.transforms is not None:
            image = self.transforms(image)

        return image, target

# %%
transforms_train = transforms.Compose([        ### torch vision transform
    # transforms.Resize(256),
#    transforms.RandomHorizontalFlip(),
#    transforms.RandomCrop(224),
    transforms.ToTensor(),
#    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
trainname
# Out:
#                                                    path  class
# 0           ./chest_xray/train/NORMAL/IM-0115-0001.jpeg      0
# 1           ./chest_xray/train/NORMAL/IM-0117-0001.jpeg      0
# 2           ./chest_xray/train/NORMAL/IM-0119-0001.jpeg      0
# 3           ./chest_xray/train/NORMAL/IM-0122-0001.jpeg      0
# 4           ./chest_xray/train/NORMAL/IM-0125-0001.jpeg      0
# ...                                                 ...    ...
# 5211  ./chest_xray/train/PNEUMONIA/person99_virus_18...      1
# 5212  ./chest_xray/train/PNEUMONIA/person9_bacteria_...      1
# 5213  ./chest_xray/train/PNEUMONIA/person9_bacteria_...      1
# 5214  ./chest_xray/train/PNEUMONIA/person9_bacteria_...      1
# 5215  ./chest_xray/train/PNEUMONIA/person9_bacteria_...      1
#
# [5216 rows x 2 columns]

# %%
train_dataset = CustomImageDataset(data = trainname, transforms=transforms_train)

# %%
next(iter(train_dataset))
# Out:
# (tensor([[[0.0863, 0.0941, 0.0941,  ..., 0.3765, 0.3686, 0.3647],
#           [0.0902, 0.0941, 0.0941,  ..., 0.3804, 0.3686, 0.3608],
#           [0.0941, 0.0941, 0.0902,  ..., 0.3882, 0.3765, 0.3686],
#           ...,
#           [0.1922, 0.1961, 0.1882,  ..., 0.4667, 0.4667, 0.4667],
#           [0.1961, 0.2039, 0.2078,  ..., 0.4824, 0.4863, 0.4824],
#           [0.2039, 0.2078, 0.2118,  ..., 0.5059, 0.5020, 0.4980]]]),
#  tensor(0))

# %%
next(iter(train_dataset))
# Out:
# (tensor([[[0.0863, 0.0941, 0.0941,  ..., 0.3765, 0.3686, 0.3647],
#           [0.0902, 0.0941, 0.0941,  ..., 0.3804, 0.3686, 0.3608],
#           [0.0941, 0.0941, 0.0902,  ..., 0.3882, 0.3765, 0.3686],
#           ...,
#           [0.1922, 0.1961, 0.1882,  ..., 0.4667, 0.4667, 0.4667],
#           [0.1961, 0.2039, 0.2078,  ..., 0.4824, 0.4863, 0.4824],
#           [0.2039, 0.2078, 0.2118,  ..., 0.5059, 0.5020, 0.4980]]]),
#  tensor(0))

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
# test_dataloader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
images, targets = next(iter(train_dataloader))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7694/1327616841.py in <module>
# ----> 1 images, targets = next(iter(train_dataloader))
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_7694/3647902939.py in __getitem__(self, idx)
#      14         img_path = self.file.iloc[idx, 0]
#      15
# ---> 16         image = plt.imread(self.data.iloc[idx,]['path'])
#      17         image = transforms.ToPILImage()(image)
#      18
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataset.py in __getattr__(self, attribute_name)
#      81             return function
#      82         else:
# ---> 83             raise AttributeError
#      84
#      85     @classmethod
#
# AttributeError:

# %%
train_features, train_labels = next(iter(train_dataloader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
img = train_features[0].squeeze()
label = train_labels[0]
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {label}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7694/708270461.py in <module>
# ----> 1 train_features, train_labels = next(iter(train_dataloader))
#       2 print(f"Feature batch shape: {train_features.size()}")
#       3 print(f"Labels batch shape: {train_labels.size()}")
#       4 img = train_features[0].squeeze()
#       5 label = train_labels[0]
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_7694/3647902939.py in __getitem__(self, idx)
#      14         img_path = self.file.iloc[idx, 0]
#      15
# ---> 16         image = plt.imread(self.data.iloc[idx,]['path'])
#      17         image = transforms.ToPILImage()(image)
#      18
#
# /home/gpu/anaconda3/envs/kyeongsoo/lib/python3.8/site-packages/torch/utils/data/dataset.py in __getattr__(self, attribute_name)
#      81             return function
#      82         else:
# ---> 83             raise AttributeError
#      84
#      85     @classmethod
#
# AttributeError:
